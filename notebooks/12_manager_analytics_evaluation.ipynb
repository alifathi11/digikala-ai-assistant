# %% [markdown]
# # 12 - Manager Analytics Evaluation
#
# - Evaluate 15 fixed manager-analytics cases.
# - Separate deterministic numeric checks from LLM-assisted answer-quality scoring.

# %%
from pathlib import Path
import json
import os
import sys

import pandas as pd
from dotenv import load_dotenv

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

load_dotenv(
    PROJECT_ROOT
    / ".env"
)

from src.rag.config import load_project_config
from src.rag.evaluation import (
    AnalyticsEvaluationDataset,
    ManagerAnalyticsEvaluator,
    analytics_failure_summary,
    build_analytics_report,
    export_analytics_manual_review,
)
from src.rag.evaluation.analytics_metrics import (
    summarize_analytics_results,
)
from src.rag.evaluation.analytics_runtime import (
    load_analytics_evaluation_context,
)

# %%
config = load_project_config(
    PROJECT_ROOT
)

evaluation_config = config[
    "analytics"
][
    "evaluation"
]

dataset = AnalyticsEvaluationDataset(
    evaluation_config[
        "cases"
    ]
)

display(
    dataset.to_frame()
)

print(
    dataset.to_frame()[
        "split"
    ].value_counts()
)

print()

print(
    dataset.to_frame()[
        "case_type"
    ].value_counts()
)
# Out:
#    case_id split                 case_type  \
# 0     a001   dev         category_overview
# 1     a002   dev            price_analysis
# 2     a003   dev       category_comparison
# 3     a004   dev              brand_policy
# 4     a005   dev  historical_price_refusal
# 5     a006  test           rating_analysis
# 6     a007  test           review_coverage
# 7     a008  test  insufficient_review_data
# 8     a009  test       category_comparison
# 9     a010  test       category_comparison
# 10    a011  test      review_volume_policy
# 11    a012  test              brand_policy
# 12    a013  test        category1_overview
# 13    a014  test          catalog_overview
# 14    a015  test      three_way_comparison
#
#                                              question  \
# 0   وضعیت کلی دسته دفتر را از نظر اندازه کاتالوگ، ...
# 1   از نظر قیمت فعلی، میانه و بازه میانی قیمت دفتر...
# 2   دفتر و زیورآلات زنانه و مردانه را از نظر قیمت،...
# 3   کدام برندها در دسته دفتر غالب‌اند و سهم بازار ...
# 4   قیمت دفترها نسبت به ماه قبل چقدر تغییر کرده و ...
# 5   کیفیت امتیازدهی محصولات دفتر چطور است و چقدر م...
# 6   پوشش بازخورد کاربران در دسته رنگ مو چقدر است و...
# 7   از تجربه کاربران درباره دسته گردنبند طلا زنانه...
# 8   دفتر و لباس دخترانه را از نظر اندازه دسته، میا...
# 9   رنگ مو و تجهیزات کمپینگ را از نظر پوشش بازخورد...
# 10  پربازخوردترین محصولات دفتر از نظر تعداد review...
# 11  برندهای دسته دفتر را بر اساس سهم بازار رتبه‌بن...
# 12  برای مدیر یک نمای کلی از دسته لباس زنانه شامل ...
# 13  در سطح کل کاتالوگ، اندازه، قیمت، پوشش بازخورد ...
# 14  این سه دسته را از نظر تعداد محصول، میانه قیمت،...
#
#                                filters  \
# 0                {'Category2': 'دفتر'}
# 1                {'Category2': 'دفتر'}
# 2                                   {}
# 3                {'Category2': 'دفتر'}
# 4                {'Category2': 'دفتر'}
# 5                {'Category2': 'دفتر'}
# 6              {'Category2': 'رنگ مو'}
# 7   {'Category2': 'گردنبند طلا زنانه'}
# 8                                   {}
# 9                                   {}
# 10               {'Category2': 'دفتر'}
# 11               {'Category2': 'دفتر'}
# 12         {'Category1': 'لباس زنانه'}
# 13                                  {}
# 14                                  {}
#
#                             comparison_categories  \
# 0                                              []
# 1                                              []
# 2                 [دفتر, زیورآلات زنانه و مردانه]
# 3                                              []
# 4                                              []
# 5                                              []
# 6                                              []
# 7                                              []
# 8                            [دفتر, لباس دخترانه]
# 9                        [رنگ مو, تجهیزات کمپینگ]
# 10                                             []
# 11                                             []
# 12                                             []
# 13                                             []
# 14  [دفتر, زیورآلات زنانه و مردانه, لباس دخترانه]
#
#                                 policy_expectations
# 0                          [rating_coverage_caveat]
# 1                                                []
# 2                          [rating_coverage_caveat]
# 3                           [brand_coverage_caveat]
# 4                        [historical_price_refusal]
# 5                          [rating_coverage_caveat]
# 6                                                []
# 7                           [zero_review_awareness]
# 8                          [rating_coverage_caveat]
# 9                          [rating_coverage_caveat]
# 10                            [review_volume_guard]
# 11                          [brand_coverage_caveat]
# 12                         [rating_coverage_caveat]
# 13  [brand_coverage_caveat, rating_coverage_caveat]
# 14                         [rating_coverage_caveat]
# split
# test    10
# dev      5
# Name: count, dtype: int64
#
# case_type
# category_comparison         3
# brand_policy                2
# category_overview           1
# price_analysis              1
# historical_price_refusal    1
# rating_analysis             1
# review_coverage             1
# insufficient_review_data    1
# review_volume_policy        1
# category1_overview          1
# catalog_overview            1
# three_way_comparison        1
# Name: count, dtype: int64

# %% [markdown]
# ## Scope validation
#
# - Validate all benchmark filters before any API call.

# %%
context = (
    load_analytics_evaluation_context(
        project_root=(
            PROJECT_ROOT
        ),
        api_key=os.environ[
            "METIS_API_KEY"
        ],
        base_url=os.environ[
            "METIS_BASE_URL"
        ],
    )
)

scope_validation = (
    dataset.validate_scopes(
        context.analytics_service
    )
)

print(
    "Scope validation:",
    scope_validation,
)

print(
    "Canonical analytics products:",
    f"{len(context.analytics_service.products):,}",
)
# Out:
# Scope validation: {'case_count': 15, 'dev_count': 5, 'test_count': 10, 'status': 'ok'}
# Canonical analytics products: 948,352

# %%
output_config = (
    evaluation_config[
        "output"
    ]
)

OUTPUT_DIR = (
    PROJECT_ROOT
    / output_config[
        "directory"
    ]
)

OUTPUT_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

CHECKPOINT_PATH = (
    OUTPUT_DIR
    / output_config[
        "checkpoint"
    ]
)

evaluator = (
    ManagerAnalyticsEvaluator(
        analytics_pipeline=(
            context.pipeline
        ),
        judge=context.judge,
        dataset=dataset,
        generic_brand_values=(
            context.analytics_config[
                "audit"
            ][
                "generic_brand_values"
            ]
        ),
        rating_max=(
            context.analytics_config[
                "aggregation"
            ][
                "product_rating_max"
            ]
        ),
        weights=(
            evaluation_config[
                "weights"
            ]
        ),
    )
)

print(
    "Checkpoint:",
    CHECKPOINT_PATH,
)

print(
    "Planned answer calls: 15"
)

print(
    "Planned judge calls: 15"
)
# Out:
# Checkpoint: /home/ali/Desktop/projects/digikala-ai-assistant/data/evaluation/analytics/analytics_checkpoint.jsonl
# Planned answer calls: 15
# Planned judge calls: 15

# %% [markdown]
# ## Run benchmark
#
# - Re-run all answer and judge calls to refresh cost telemetry.

# %%
FORCE_RERUN = True

results = evaluator.run(
    checkpoint_path=(
        CHECKPOINT_PATH
    ),
    splits=[
        "dev",
        "test",
    ],
    force=(
        FORCE_RERUN
    ),
)

print()
print(
    "Status:"
)

print(
    results[
        "status"
    ].value_counts(
        dropna=False
    )
)
# Out:
# [1/15] a001: running
# [2/15] a002: running
# [3/15] a003: running
# [4/15] a004: running
# [5/15] a005: running
# [6/15] a006: running
# [7/15] a007: running
# [8/15] a008: running
# [9/15] a009: running
# [10/15] a010: running
# [11/15] a011: running
# [12/15] a012: running
# [13/15] a013: running
# [14/15] a014: running
# [15/15] a015: running
#
# Status:
# status
# ok    15
# Name: count, dtype: int64

# %% [markdown]
# ## Aggregate metrics
#
# - Summarize DEV, TEST, and overall results.

# %%
summary = (
    summarize_analytics_results(
        results
    )
)

display(
    summary
)
# Out:
#   split  cases  successful_cases  overall_judge_score  numeric_faithfulness  \
# 0   dev      5                 5                 4.83                   1.0
# 1  test     10                10                 4.86                   1.0
# 2   ALL     15                15                 4.85                   1.0
#
#    fact_value_accuracy  scope_product_count_accuracy  \
# 0                  1.0                           1.0
# 1                  1.0                           1.0
# 2                  1.0                           1.0
#
#    comparison_fact_accuracy  rendered_metric_accuracy  \
# 0                       1.0                       1.0
# 1                       1.0                       1.0
# 2                       1.0                       1.0
#
#    policy_guard_configuration  ...  completeness  relevance  \
# 0                         1.0  ...      4.600000        5.0
# 1                         1.0  ...      4.700000        5.0
# 2                         1.0  ...      4.666667        5.0
#
#    managerial_usefulness  instruction_following  answer_latency_ms  \
# 0                    4.6               5.000000       11326.183555
# 1                    4.9               4.900000       15768.561481
# 2                    4.8               4.933333       14287.768839
#
#    judge_latency_ms  evaluation_latency_ms  answer_total_tokens  \
# 0       9943.458286           21766.693495          3214.800000
# 1      11763.820787           28122.223474          3533.900000
# 2      11157.033286           26003.713481          3427.533333
#
#    judge_total_tokens  answer_latency_p95_ms
# 0         4081.000000           16799.700247
# 1         4462.500000           23982.097740
# 2         4335.333333           23596.332743
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Deterministic metrics
#
# - Verify numeric faithfulness, aggregation, filters, comparisons, and rendering.

# %%
deterministic_columns = [
    "case_id",
    "split",
    "case_type",
    "numeric_faithfulness",
    "fact_value_accuracy",
    "scope_product_count_accuracy",
    "comparison_fact_accuracy",
    "rendered_metric_accuracy",
    "policy_guard_configuration",
]

display(
    results[
        [
            column
            for column
            in deterministic_columns
            if column
            in results.columns
        ]
    ]
)
# Out:
#    case_id split                 case_type  numeric_faithfulness  \
# 0     a001   dev         category_overview                   1.0
# 1     a002   dev            price_analysis                   1.0
# 2     a003   dev       category_comparison                   1.0
# 3     a004   dev              brand_policy                   1.0
# 4     a005   dev  historical_price_refusal                   1.0
# 5     a006  test           rating_analysis                   1.0
# 6     a007  test           review_coverage                   1.0
# 7     a008  test  insufficient_review_data                   1.0
# 8     a009  test       category_comparison                   1.0
# 9     a010  test       category_comparison                   1.0
# 10    a011  test      review_volume_policy                   1.0
# 11    a012  test              brand_policy                   1.0
# 12    a013  test        category1_overview                   1.0
# 13    a014  test          catalog_overview                   1.0
# 14    a015  test      three_way_comparison                   1.0
#
#     fact_value_accuracy  scope_product_count_accuracy  \
# 0                   1.0                           1.0
# 1                   1.0                           1.0
# 2                   1.0                           1.0
# 3                   1.0                           1.0
# 4                   1.0                           1.0
# 5                   1.0                           1.0
# 6                   1.0                           1.0
# 7                   1.0                           1.0
# 8                   1.0                           1.0
# 9                   1.0                           1.0
# 10                  1.0                           1.0
# 11                  1.0                           1.0
# 12                  1.0                           1.0
# 13                  1.0                           1.0
# 14                  1.0                           1.0
#
#     comparison_fact_accuracy  rendered_metric_accuracy  \
# 0                        NaN                       1.0
# 1                        NaN                       1.0
# 2                        1.0                       1.0
# 3                        NaN                       1.0
# 4                        NaN                       1.0
# 5                        NaN                       1.0
# 6                        NaN                       1.0
# 7                        NaN                       1.0
# 8                        1.0                       1.0
# 9                        1.0                       1.0
# 10                       NaN                       1.0
# 11                       NaN                       1.0
# 12                       NaN                       1.0
# 13                       NaN                       1.0
# 14                       1.0                       1.0
#
#     policy_guard_configuration
# 0                          1.0
# 1                          NaN
# 2                          1.0
# 3                          1.0
# 4                          1.0
# 5                          1.0
# 6                          NaN
# 7                          1.0
# 8                          1.0
# 9                          1.0
# 10                         1.0
# 11                         1.0
# 12                         1.0
# 13                         1.0
# 14                         1.0

# %% [markdown]
# ## LLM-assisted quality
#
# - Score interpretation, grounding, caveats, completeness, and usefulness.

# %%
quality_columns = [
    "case_id",
    "split",
    "case_type",
    "overall_judge_score",
    "correctness",
    "groundedness",
    "caveat_compliance",
    "completeness",
    "relevance",
    "managerial_usefulness",
    "instruction_following",
    "judge_failure_tags",
]

display(
    results[
        quality_columns
    ].sort_values(
        [
            "split",
            "overall_judge_score",
        ],
        ascending=[
            True,
            True,
        ],
    )
)
# Out:
#    case_id split                 case_type  overall_judge_score  correctness  \
# 3     a004   dev              brand_policy                 4.65          5.0
# 1     a002   dev            price_analysis                 4.75          4.0
# 0     a001   dev         category_overview                 4.80          5.0
# 2     a003   dev       category_comparison                 4.95          5.0
# 4     a005   dev  historical_price_refusal                 5.00          5.0
# 11    a012  test              brand_policy                 4.30          4.0
# 13    a014  test          catalog_overview                 4.65          5.0
# 10    a011  test      review_volume_policy                 4.80          5.0
# 12    a013  test        category1_overview                 4.85          5.0
# 5     a006  test           rating_analysis                 5.00          5.0
# 6     a007  test           review_coverage                 5.00          5.0
# 7     a008  test  insufficient_review_data                 5.00          5.0
# 8     a009  test       category_comparison                 5.00          5.0
# 9     a010  test       category_comparison                 5.00          5.0
# 14    a015  test      three_way_comparison                 5.00          5.0
#
#     groundedness  caveat_compliance  completeness  relevance  \
# 3            5.0                5.0           3.0        5.0
# 1            5.0                5.0           5.0        5.0
# 0            4.0                5.0           5.0        5.0
# 2            5.0                5.0           5.0        5.0
# 4            5.0                5.0           5.0        5.0
# 11           4.0                5.0           4.0        5.0
# 13           4.0                5.0           4.0        5.0
# 10           5.0                4.0           5.0        5.0
# 12           5.0                5.0           4.0        5.0
# 5            5.0                5.0           5.0        5.0
# 6            5.0                5.0           5.0        5.0
# 7            5.0                5.0           5.0        5.0
# 8            5.0                5.0           5.0        5.0
# 9            5.0                5.0           5.0        5.0
# 14           5.0                5.0           5.0        5.0
#
#     managerial_usefulness  instruction_following  \
# 3                     4.0                    5.0
# 1                     5.0                    5.0
# 0                     5.0                    5.0
# 2                     4.0                    5.0
# 4                     5.0                    5.0
# 11                    4.0                    4.0
# 13                    5.0                    5.0
# 10                    5.0                    5.0
# 12                    5.0                    5.0
# 5                     5.0                    5.0
# 6                     5.0                    5.0
# 7                     5.0                    5.0
# 8                     5.0                    5.0
# 9                     5.0                    5.0
# 14                    5.0                    5.0
#
#                               judge_failure_tags
# 3                      [missed_requested_metric]
# 1                                             []
# 0                                             []
# 2                                             []
# 4                                             []
# 11  [unsupported_claim, missed_requested_metric]
# 13  [unsupported_claim, missed_requested_metric]
# 10                                            []
# 12                                            []
# 5                                             []
# 6                                             []
# 7                                             []
# 8                                             []
# 9                                             []
# 14                                            []

# %% [markdown]
# ## Failure analysis
#
# - Inspect policy or quality failures.

# %%
failures = (
    analytics_failure_summary(
        results
    )
)

display(
    failures
)

flagged = results[
    results[
        "judge_failure_tags"
    ].apply(
        lambda value: (
            isinstance(
                value,
                list,
            )
            and len(
                value
            )
            > 0
        )
    )
    |
    (
        results[
            "numeric_faithfulness"
        ]
        < 1.0
    )
    |
    (
        results[
            "fact_value_accuracy"
        ]
        < 1.0
    )
]

display(
    flagged[
        [
            "case_id",
            "split",
            "case_type",
            "question",
            "answer",
            "overall_judge_score",
            "judge_failure_tags",
            "judge_summary_reason",
        ]
    ]
)
# Out:
#                    failure  count
# 0  missed_requested_metric      3
# 1        unsupported_claim      2
#    case_id split         case_type  \
# 3     a004   dev      brand_policy
# 11    a012  test      brand_policy
# 13    a014  test  catalog_overview
#
#                                              question  \
# 3   کدام برندها در دسته دفتر غالب‌اند و سهم بازار ...
# 11  برندهای دسته دفتر را بر اساس سهم بازار رتبه‌بن...
# 13  در سطح کل کاتالوگ، اندازه، قیمت، پوشش بازخورد ...
#
#                                                answer  overall_judge_score  \
# 3   سهم بازار برندها از این داده قابل اعلام نیست؛ ...                 4.65
# 11  رتبه‌بندی سهم بازار و تعیین رهبر بازار از داده...                 4.30
# 13  کاتالوگ شامل 948,352 محصول است. قیمت فعلی برای...                 4.65
#
#                               judge_failure_tags  \
# 3                      [missed_requested_metric]
# 11  [unsupported_claim, missed_requested_metric]
# 13  [unsupported_claim, missed_requested_metric]
#
#                                  judge_summary_reason
# 3   پاسخ از نظر تفسیر و رعایت سیاست برند بسیار درس...
# 11  پاسخ از نظر سیاست داده و پرهیز از ادعای سهم با...
# 13  پاسخ از نظر محاسبات و محدودیت‌های داده بسیار م...

# %% [markdown]
# ## Runtime telemetry
#
# - Report answer and judge latency, tokens, and cost.

# %%
telemetry = pd.DataFrame(
    [
        {
            "split": split,
            "mean_answer_latency_sec": (
                group[
                    "answer_latency_ms"
                ].mean()
                / 1000
            ),
            "p95_answer_latency_sec": (
                group[
                    "answer_latency_ms"
                ].quantile(
                    0.95
                )
                / 1000
            ),
            "mean_eval_latency_sec": (
                group[
                    "evaluation_latency_ms"
                ].mean()
                / 1000
            ),
            "answer_tokens": int(
                group[
                    "answer_total_tokens"
                ].sum()
            ),
            "judge_tokens": int(
                group[
                    "judge_total_tokens"
                ].sum()
            ),
        }
        for split, group
        in results.groupby(
            "split",
            sort=False,
        )
    ]
)

display(
    telemetry
)

answer_cost = pd.to_numeric(
    results[
        "answer_cost_usd"
    ],
    errors="coerce",
)

judge_cost = pd.to_numeric(
    results[
        "judge_cost_usd"
    ],
    errors="coerce",
)

if (
    answer_cost.notna().any()
    or judge_cost.notna().any()
):
    print(
        "Answer cost USD:",
        answer_cost.sum(
            min_count=1
        ),
    )

    print(
        "Judge cost USD:",
        judge_cost.sum(
            min_count=1
        ),
    )
else:
    print(
        "Cost not computed: pricing fields are null."
    )
# Out:
#   split  mean_answer_latency_sec  p95_answer_latency_sec  \
# 0   dev                11.326184               16.799700
# 1  test                15.768561               23.982098
#
#    mean_eval_latency_sec  answer_tokens  judge_tokens
# 0              21.766693          16074         20405
# 1              28.122223          35339         44625
# Answer cost USD: 0.09517300000000001
# Judge cost USD: 0.11143000000000002

# %% [markdown]
# ## Save artifacts
#
# - Save case results, metrics, manual-review CSV, and JSON report.

# %%
CASE_RESULTS_PATH = (
    OUTPUT_DIR
    / output_config[
        "case_results"
    ]
)

METRICS_PATH = (
    OUTPUT_DIR
    / output_config[
        "metrics"
    ]
)

MANUAL_REVIEW_PATH = (
    OUTPUT_DIR
    / output_config[
        "manual_review"
    ]
)

REPORT_PATH = (
    OUTPUT_DIR
    / output_config[
        "report"
    ]
)

serializable = results.copy()

for column in [
    "filters",
    "comparison_categories",
    "policy_expectations",
    "fact_value_errors",
    "judge_failure_tags",
    "result",
    "judge",
]:
    if column in serializable.columns:
        serializable[
            column
        ] = serializable[
            column
        ].apply(
            lambda value: json.dumps(
                value,
                ensure_ascii=False,
                default=str,
            )
        )

serializable.to_csv(
    CASE_RESULTS_PATH,
    index=False,
    encoding="utf-8-sig",
)

summary.to_parquet(
    METRICS_PATH,
    index=False,
)

export_analytics_manual_review(
    frame=results,
    path=(
        MANUAL_REVIEW_PATH
    ),
)

report = (
    build_analytics_report(
        results
    )
)

with REPORT_PATH.open(
    "w",
    encoding="utf-8",
) as handle:
    json.dump(
        report,
        handle,
        ensure_ascii=False,
        indent=2,
        default=str,
    )

print(
    "Saved:",
    CASE_RESULTS_PATH,
)

print(
    "Saved:",
    METRICS_PATH,
)

print(
    "Saved:",
    MANUAL_REVIEW_PATH,
)

print(
    "Saved:",
    REPORT_PATH,
)
# Out:
# Saved: /home/ali/Desktop/projects/digikala-ai-assistant/data/evaluation/analytics/analytics_case_results.csv
# Saved: /home/ali/Desktop/projects/digikala-ai-assistant/data/evaluation/analytics/analytics_metrics.parquet
# Saved: /home/ali/Desktop/projects/digikala-ai-assistant/data/evaluation/analytics/analytics_manual_review.csv
# Saved: /home/ali/Desktop/projects/digikala-ai-assistant/data/evaluation/analytics/analytics_report.json

# %% [markdown]
# ## Reporting note
#
# - Treat LLM judge scores as proxy evaluation, not independent human annotation.
