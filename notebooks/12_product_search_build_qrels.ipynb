# %% [markdown]
# # 12 — Build Product Search Qrels
#
# ۳۰ query، پنج intent، dev/test ثابت، relevance grade از ۰ تا ۳.
#
# تا قبل از review دستی، labelها **LLM teacher proxy** هستند.

# %%
import os
from pathlib import Path
import sys
from dotenv import load_dotenv

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
load_dotenv(PROJECT_ROOT / ".env")

from src.rag.config import load_config
from src.rag.evaluation.product_search_queries import load_product_search_queries, assign_stratified_split
from src.rag.evaluation.product_search_runtime import load_product_search_evaluation_context
from src.rag.evaluation.product_search_qrels import ProductSearchQrelsBuilder

# %%
cfg = load_config(PROJECT_ROOT / "configs" / "product_search_evaluation.yaml")["product_search_evaluation"]
queries = load_product_search_queries(PROJECT_ROOT / "configs" / "product_search_eval_queries.yaml")
queries = assign_stratified_split(queries, test_fraction=cfg["test_fraction"], seed=cfg["seed"])

EVAL_DIR = PROJECT_ROOT / "data" / "evaluation" / "product_search"
EVAL_DIR.mkdir(parents=True, exist_ok=True)
queries.to_csv(EVAL_DIR / "queries.csv", index=False)

display(queries.groupby(["query_type", "split"]).size().unstack(fill_value=0))
print("Queries:", len(queries))
print("Expected judge calls:", len(queries))
# Out:
# split             dev  test
# query_type
# attribute           4     2
# brand               4     2
# experiential        4     2
# multi_constraint    4     2
# negative            4     2
# Queries: 30
# Expected judge calls: 30

# %%
context = load_product_search_evaluation_context(
    project_root=PROJECT_ROOT,
    api_key=os.environ["METIS_API_KEY"],
    base_url=os.environ["METIS_BASE_URL"],
)
pool_cfg = cfg["qrel_pool"]
builder = ProductSearchQrelsBuilder(
    metadata_retriever=context.metadata,
    review_evidence=context.review_evidence,
    judge=context.judge,
    hybrid_pool_k=pool_cfg["hybrid_k"],
    dense_pool_k=pool_cfg["dense_k"],
    sparse_pool_k=pool_cfg["sparse_k"],
    rescue_pool_k=pool_cfg["rescue_k"],
    rescue_fragment_k=pool_cfg["rescue_fragment_k"],
    rescue_max_fragments=pool_cfg["rescue_max_fragments"],
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
result = builder.build(
    queries=queries,
    qrels_path=EVAL_DIR / "qrels.parquet",
    telemetry_path=EVAL_DIR / "qrels_telemetry.csv",
    manual_review_path=EVAL_DIR / "qrels_manual_review.csv",
    resume=True,
)
qrels = result["qrels"]
telemetry = result["telemetry"]
print("Qrel rows:", len(qrels))
print("Queries judged:", qrels["query_id"].nunique())
display(qrels["teacher_grade"].value_counts().sort_index())
display(qrels["teacher_confidence"].value_counts())
# Out:
# Qrel rows: 454
# Queries judged: 30
# teacher_grade
# 0    256
# 1     56
# 2     78
# 3     64
# Name: count, dtype: int64
# teacher_confidence
# high      380
# medium     73
# low         1
# Name: count, dtype: int64

# %%
display(
    qrels[qrels["manual_review_priority"]][
        ["query_id", "query", "id", "title_fa", "teacher_grade", "teacher_confidence", "teacher_reason"]
    ].head(60)
)
print("Manual review CSV:", EVAL_DIR / "qrels_manual_review.csv")
print("برای گزارش نهایی حداقل همه ردیف‌های TEST را دستی review کن.")
# Out:
#     query_id                                query        id  \
# 0       q001                  شامپو ضد ریزش سریتا    711943
# 1       q001                  شامپو ضد ریزش سریتا   6552521
# 6       q001                  شامپو ضد ریزش سریتا   8021274
# 7       q001                  شامپو ضد ریزش سریتا   3832629
# 10      q001                  شامپو ضد ریزش سریتا    471187
# 16      q002       ضد آفتاب ژیناژن مناسب پوست چرب  12565854
# 19      q002       ضد آفتاب ژیناژن مناسب پوست چرب  10985328
# 21      q002       ضد آفتاب ژیناژن مناسب پوست چرب  12565742
# 22      q002       ضد آفتاب ژیناژن مناسب پوست چرب  11286406
# 26      q002       ضد آفتاب ژیناژن مناسب پوست چرب   1110394
# 33      q003                     کرم آبرسان سیمپل   9284669
# 34      q003                     کرم آبرسان سیمپل   2044199
# 35      q003                     کرم آبرسان سیمپل   1465399
# 36      q003                     کرم آبرسان سیمپل  10621003
# 37      q003                     کرم آبرسان سیمپل   8490665
# 38      q003                     کرم آبرسان سیمپل   4561115
# 39      q003                     کرم آبرسان سیمپل  10819838
# 40      q003                     کرم آبرسان سیمپل   4512773
# 41      q003                     کرم آبرسان سیمپل  12414045
# 42      q003                     کرم آبرسان سیمپل   5148334
# 43      q003                     کرم آبرسان سیمپل   6970514
# 44      q003                     کرم آبرسان سیمپل   7148180
# 45      q003                     کرم آبرسان سیمپل   8079131
# 46      q003                     کرم آبرسان سیمپل   5168354
# 47      q003                     کرم آبرسان سیمپل  11790936
# 48      q003                     کرم آبرسان سیمپل   7877573
# 49      q004               پاوربانک شیائومی 20000    104647
# 54      q004               پاوربانک شیائومی 20000   4846747
# 55      q004               پاوربانک شیائومی 20000   6762289
# 60      q004               پاوربانک شیائومی 20000   9248497
# 61      q004               پاوربانک شیائومی 20000  10275534
# 69      q005                  هندزفری بی سیم انکر  12089628
# 70      q005                  هندزفری بی سیم انکر   6050858
# 71      q005                  هندزفری بی سیم انکر   3257976
# 72      q005                  هندزفری بی سیم انکر   6745354
# 73      q005                  هندزفری بی سیم انکر   6242463
# 74      q005                  هندزفری بی سیم انکر   3258001
# 75      q005                  هندزفری بی سیم انکر   3257948
# 76      q005                  هندزفری بی سیم انکر   6242655
# 77      q005                  هندزفری بی سیم انکر    368558
# 78      q005                  هندزفری بی سیم انکر    368562
# 79      q005                  هندزفری بی سیم انکر    368569
# 80      q005                  هندزفری بی سیم انکر   6602896
# 81      q005                  هندزفری بی سیم انکر   8724815
# 82      q005                  هندزفری بی سیم انکر   9939333
# 83      q005                  هندزفری بی سیم انکر  11932356
# 84      q005                  هندزفری بی سیم انکر    817776
# 85      q006                   ماشین اصلاح فیلیپس     20401
# 86      q006                   ماشین اصلاح فیلیپس   8631170
# 87      q006                   ماشین اصلاح فیلیپس     20402
# 88      q006                   ماشین اصلاح فیلیپس    117877
# 89      q006                   ماشین اصلاح فیلیپس   8959198
# 92      q006                   ماشین اصلاح فیلیپس    151626
# 94      q006                   ماشین اصلاح فیلیپس   1520504
# 101     q007  ضد آفتاب بی رنگ SPF50 برای پوست چرب  10985328
# 102     q007  ضد آفتاب بی رنگ SPF50 برای پوست چرب   6733478
# 103     q007  ضد آفتاب بی رنگ SPF50 برای پوست چرب    733670
# 104     q007  ضد آفتاب بی رنگ SPF50 برای پوست چرب  11398256
# 105     q007  ضد آفتاب بی رنگ SPF50 برای پوست چرب   5426356
# 106     q007  ضد آفتاب بی رنگ SPF50 برای پوست چرب  12431846
#
#                                               title_fa  teacher_grade  \
# 0    شامپو ضد ریزش سریتا مدل پرومین مناسب برای موها...              3
# 1    شامپو تقویت کننده و ضد ریزش سریتا مدل Fortifyi...              3
# 6    شامپو ضد ریزش مو سریتا مدل مینوتا حجم 200 میلی...              3
# 7    شامپو ضد ریزش مو سریتا مدل مینوتا مناسب برای م...              3
# 10   شامپو تقویت کننده و ضد ریزش سریتا مدل کافئین م...              3
# 16   کرم ضد آفتاب رنگی ژیناژن SPF 50 مدل 03 ‌مناسب ...              3
# 19   فلوئید ضد آفتاب بی رنگ نوکس SPF50 مدل LIGHT من...              0
# 21   کرم ضد آفتاب رنگی ژیناژن SPF 50 مدل 02 ‌مناسب ...              3
# 22   فلوئید ضد آفتاب بی رنگ اوریاژ +SPF50 مدل Hysea...              0
# 26   کرم ضد آفتاب رنگی اریکه مدل SPF50 مناسب پوست ه...              0
# 33        کرم آبرسان سیمپل مدل Light حجم 125 میلی لیتر              3
# 34                           سایه ابرو دوسه شماره S4-1              0
# 35                           سایه ابرو دوسه شماره S2-1              0
# 36         کرم آبرسان سیمپل مدل Rich حجم 125 میلی لیتر              3
# 37   کرم آبرسان سیمپل مدل Hydrating Booster حجم 25 ...              3
# 38                            سایه ابرو ورورا شماره V4              0
# 39                   کلاه کپ پسرانه طرح پرندگان خشمگین              0
# 40   کرم آبرسان لوازم آرایشی سیمپل مدل light حجم 12...              3
# 41            ژل آبرسان سیمپل مدل 001 حجم 25 میلی لیتر              1
# 42    ژل آبرسان سیمپل مدل WATER BOOST حجم 50 میلی لیتر              1
# 43   کرم دور چشم سیمپل مدل Revitalising حجم 15 میلی...              1
# 44   کرم دور چشم سیمپل مدل Regeneration حجم 15 میلی...              1
# 45           کرم دور چشم سیمپل مدل 01 حجم 15 میلی لیتر              1
# 46           کرم مغذی سیمپل مدل RICH حجم 125 میلی لیتر              2
# 47   کرم ضد آفتاب سیمپل مدل triple protect حجم 40 م...              1
# 48   کرم مرطوب کننده سیمپل مدل light حجم 125 میلی لیتر              3
# 49                         ترازو هوشمند شیائومی مدل Mi              0
# 54                 ترازو دیجیتال شیائومی مدل XMTZC04HM              0
# 55                 ترازو دیجیتال شیائومی مدل XMTZC05HM              0
# 60          ترازو دیجیتال شیائومی مدل Mi_composition 2              0
# 61                 ماساژور دستی شیائومی مدل MJJMQ02-ZJ              0
# 69                   میکروفن بی سیم آر اند بی مدل RB-1              0
# 70                 فلش کارت آموزش اعداد انتشارات طلایه              0
# 71   کتاب ایستگاه خلاقیت سری کاردستی آسان اثر م محم...              0
# 72                ست میکروفن بی سیم جی بی ال مدل w-one              0
# 73               دندان گیر کودک بی بی سیم مدل Bo2551.1              0
# 74   کتاب ایستگاه خلاقیت سری کاردستی آسان اثر م محم...              0
# 75   کتاب ایستگاه خلاقیت سری کاردستی آسان اثر م محم...              0
# 76               دندان گیر کودک بی بی سیم مدل Bo2551.2              0
# 77                      بی سیم اسباب بازی مدل Avengers              0
# 78                    بی سیم اسباب بازی مدل Spider-Man              0
# 79                        بی سیم اسباب بازی مدل Planes              0
# 80                          بی سیم واکی تاکی مدل ارتشی              0
# 81                   میکروفون بی سیم تسکو مدل TMIC5500              0
# 82         بازر ماهیگیری اوساکو مدل بی سیم بسته 4 عددی              0
# 83                              میکروفن بی سیم مدل p3s              0
# 84               میکروفون بی سیم کیمافون مدل KM-G130-1              0
# 85                ماشین اصلاح صورت فیلیپس مدل AT890/20              3
# 86                  تیغ یدک ماشین اصلاح فیلیپس مدل P98              1
# 87                ماشین اصلاح صورت فیلیپس مدل PT860/16              3
# 88                ماشین اصلاح صورت فیلیپس مدل S7370/12              3
# 89      تیغ یدک ماشین اصلاح فیلیپس مدل P98 بسته 3 عددی              1
# 92                ماشین اصلاح صورت فیلیپس مدل S9911/11              3
# 94                  ماشین اصلاح صورت فیلیپس مدل HQ7320              3
# 101  فلوئید ضد آفتاب بی رنگ نوکس SPF50 مدل LIGHT من...              1
# 102  فلوئید ضد آفتاب بی رنگ الارو SPF50 مدل Ultra L...              3
# 103  کرم ضد آفتاب بی رنگ درمالیفت مدل SPF50 مناسب پ...              3
# 104  فلوئید ضد آفتاب بی رنگ ویشی SPF50 مدل مات مناس...              3
# 105  کرم ضد آفتاب بی رنگ ژیناژن مدل SPF50 مناسب پوس...              3
# 106  کرم ضد آفتاب بی رنگ بایومارین SPF50 مدل 01 منا...              2
#
#     teacher_confidence                                     teacher_reason
# 0                 high  شامل شامپو ضد ریزش سریتا است و تونیک نیز به‌هم...
# 1                 high     شامپو تقویت‌کننده و ضد ریزش از برند سریتا است.
# 6                 high            مجموعه دو عددی شامپو ضد ریزش سریتا است.
# 7                 high  شامپو ضد ریزش سریتا برای موهای خشک است؛ رضایت ...
# 10                high  شامپو تقویت‌کننده و ضد ریزش سریتا است؛ نظر نیز...
# 16                high      ضد آفتاب ژیناژن و صراحتاً مناسب پوست چرب است.
# 19                high                          برند نوکس است، نه ژیناژن.
# 21                high  کرم ضد آفتاب رنگی ژیناژن و مناسب پوست چرب است؛...
# 22                high                        برند اوریاژ است، نه ژیناژن.
# 26                high                         برند اریکه است، نه ژیناژن.
# 33                high   کرم آبرسان از برند سیمپل با نوع محصول منطبق است.
# 34                high  سایه ابرو است و با نوع محصول درخواستی مطابقت ن...
# 35                high  سایه ابرو است و با نوع محصول درخواستی مطابقت ن...
# 36                high  کرم آبرسان سیمپل است و با درخواست کاملاً منطبق...
# 37                high                      کرم آبرسان از برند سیمپل است.
# 38                high           سایه ابرو است و محصول آبرسان سیمپل نیست.
# 39                high              کلاه پسرانه است و کاملاً نامرتبط است.
# 40                high  کرم آبرسان سیمپل مدل Light است و دقیقاً منطبق ...
# 41                high  برند سیمپل و کارکرد آبرسان دارد، اما نوع محصول...
# 42                high  ژل آبرسان سیمپل است، نه کرم؛ همچنین نظر ارسالی...
# 43                high  کرم دور چشم سیمپل است، نه کرم آبرسان صورت/مرطو...
# 44                high   کرم دور چشم سیمپل است و نوع محصول درخواستی نیست.
# 45                high  کرم دور چشم سیمپل است و با کرم آبرسان متفاوت است.
# 46              medium  کرم مغذی سیمپل در دسته مرطوب‌کننده است، اما عن...
# 47                high                  ضدآفتاب سیمپل است، نه کرم آبرسان.
# 48                high  کرم مرطوب‌کننده سیمپل مدل Light است؛ عنوان و د...
# 49                high             ترازوی شیائومی است، نه پاوربانک ۲۰۰۰۰.
# 54                high           ترازوی دیجیتال شیائومی است، نه پاوربانک.
# 55                high           ترازوی دیجیتال شیائومی است، نه پاوربانک.
# 60                high           ترازوی دیجیتال شیائومی است، نه پاوربانک.
# 61                high             ماساژور دستی شیائومی است، نه پاوربانک.
# 69                high  میکروفن بی‌سیم است، نه هندزفری؛ برند نیز انکر ...
# 70                high  فلش‌کارت آموزشی است و ارتباطی با هندزفری بی‌سی...
# 71                high             کتاب کاردستی است و محصول موردنظر نیست.
# 72                high  ست میکروفن بی‌سیم جی‌بی‌ال است، نه هندزفری و ن...
# 73                high     دندان‌گیر کودک است و ارتباطی با هندزفری ندارد.
# 74                high             کتاب کاردستی است و محصول موردنظر نیست.
# 75                high             کتاب کاردستی است و محصول موردنظر نیست.
# 76                high     دندان‌گیر کودک است و ارتباطی با هندزفری ندارد.
# 77                high     بی‌سیم اسباب‌بازی است، نه هندزفری بی‌سیم انکر.
# 78                high     بی‌سیم اسباب‌بازی است، نه هندزفری بی‌سیم انکر.
# 79                high     بی‌سیم اسباب‌بازی است، نه هندزفری بی‌سیم انکر.
# 80                high  واکی‌تاکی اسباب‌بازی است، نه هندزفری؛ برند انک...
# 81                high  میکروفون بی‌سیم تسکو است، نه هندزفری و نه برند...
# 82                high  بازر ماهیگیری است و ارتباطی با هندزفری بی‌سیم ...
# 83                high  میکروفن بی‌سیم است، نه هندزفری؛ برند انکر نیز ...
# 84                high       میکروفون بی‌سیم است، نه هندزفری بی‌سیم انکر.
# 85                high  ماشین اصلاح صورت با برند فیلیپس است و دقیقاً ب...
# 86                high  تیغ یدک ماشین اصلاح فیلیپس است، نه خودِ ماشین ...
# 87                high  ماشین اصلاح صورت از برند فیلیپس است و با درخوا...
# 88                high  ماشین اصلاح صورت فیلیپس است و نوع و برند موردن...
# 89                high    بسته تیغ یدک است و خود ماشین اصلاح فیلیپس نیست.
# 92                high  ماشین اصلاح صورت فیلیپس است و با جست‌وجوی کارب...
# 94                high               ماشین اصلاح صورت از برند فیلیپس است.
# 101               high  نوع، بی‌رنگ بودن، SPF50 و پوست چرب در عنوان مط...
# 102               high  فلوئید ضدآفتاب بی‌رنگ SPF50 مخصوص پوست چرب و م...
# 103               high  ضدآفتاب بی‌رنگ SPF50 مخصوص پوست چرب است؛ نظر ن...
# 104               high  فلوئید ضدآفتاب بی‌رنگ SPF50 مات برای پوست چرب ...
# 105             medium  کرم ضدآفتاب بی‌رنگ SPF50 مخصوص پوست چرب است و ...
# 106               high  عنوان دقیقاً ضدآفتاب بی‌رنگ SPF50 مناسب پوست چ...
# Manual review CSV: /home/ali/Desktop/projects/digikala-ai-assistant/data/evaluation/product_search/qrels_manual_review.csv
# برای گزارش نهایی حداقل همه ردیف‌های TEST را دستی review کن.

# %% [markdown]
# ## Evaluation-only lexical rescue
#
# این مرحله production retriever را تغییر نمی‌دهد. qrels قبلی حفظ می‌شوند و
# فقط candidateهای جدیدی که با subqueryهای lexical مستقل پیدا شده‌اند judge
# می‌شوند.

# %%
rescue_result = builder.augment_with_rescue(
    queries=queries,
    qrels_path=(
        EVAL_DIR
        / "qrels.parquet"
    ),
    telemetry_path=(
        EVAL_DIR
        / "qrels_telemetry.csv"
    ),
    manual_review_path=(
        EVAL_DIR
        / "qrels_manual_review.csv"
    ),
)

qrels = rescue_result["qrels"]
telemetry = rescue_result["telemetry"]

print(
    "New rescue qrel rows:",
    rescue_result[
        "new_qrel_rows"
    ],
)

print(
    "Total qrel rows:",
    len(qrels),
)
# Out:
# New rescue qrel rows: 133
# Total qrel rows: 587

# %%
query_audit = (
    qrels.groupby(
        [
            "query_id",
            "query_type",
            "query",
            "split",
        ]
    )
    .agg(
        pool_size=(
            "id",
            "size",
        ),
        relevant_ge2=(
            "teacher_grade",
            lambda values: int(
                (
                    values
                    >= 2
                ).sum()
            ),
        ),
        rescue_candidates=(
            "rescue_pool_rank",
            lambda values: int(
                values.notna().sum()
            ),
        ),
    )
    .reset_index()
)

zero_positive = query_audit[
    query_audit[
        "relevant_ge2"
    ]
    == 0
]

print(
    "Queries with zero relevant products "
    "in judged pool:",
    len(zero_positive),
)

display(zero_positive)

display(
    qrels[
        qrels[
            "rescue_pool_rank"
        ].notna()
    ][
        [
            "query_id",
            "query",
            "id",
            "title_fa",
            "rescue_fragment",
            "rescue_pool_rank",
            "teacher_grade",
            "teacher_reason",
        ]
    ].head(80)
)
# Out:
# Queries with zero relevant products in judged pool: 8
#    query_id        query_type  \
# 3      q004             brand
# 4      q005             brand
# 8      q009         attribute
# 9      q010         attribute
# 14     q015      experiential
# 22     q023          negative
# 26     q027  multi_constraint
# 27     q028  multi_constraint
#
#                                                 query split  pool_size  \
# 3                              پاوربانک شیائومی 20000   dev         20
# 4                                 هندزفری بی سیم انکر  test         21
# 8              سرخ کن بدون روغن با ظرفیت حداقل 6 لیتر  test         19
# 9                               ماوس بی سیم ارگونومیک  test         21
# 14                          جارو شارژی سبک با مکش خوب   dev         19
# 22                               پاوربانک که داغ نکنه   dev         16
# 26  هندزفری بلوتوث با باتری خوب و میکروفون مناسب تماس   dev         19
# 27                      پاوربانک 20000 فست شارژ و سبک   dev         17
#
#     relevant_ge2  rescue_candidates
# 3              0                  0
# 4              0                  5
# 8              0                  6
# 9              0                  5
# 14             0                  5
# 22             0                  0
# 26             0                  7
# 27             0                  3
#     query_id                           query        id  \
# 454     q001             شامپو ضد ریزش سریتا    894006
# 455     q001             شامپو ضد ریزش سریتا    370711
# 456     q001             شامپو ضد ریزش سریتا   3832551
# 457     q001             شامپو ضد ریزش سریتا   5408041
# 458     q001             شامپو ضد ریزش سریتا   4344687
# ..       ...                             ...       ...
# 529     q016   اسپیکر با صدای شفاف و بیس خوب  12385814
# 530     q016   اسپیکر با صدای شفاف و بیس خوب  10649965
# 531     q017  کفش راحت برای پیاده روی طولانی   8854897
# 532     q017  کفش راحت برای پیاده روی طولانی  10794129
# 533     q017  کفش راحت برای پیاده روی طولانی  12555767
#
#                                               title_fa rescue_fragment  \
# 454                   شامپو ضد ریزش موی کلینیک مدل 233   شامپو ضد ریزش
# 455        شامپو ضد ریزش مو درمالاین حجم 250 میلی لیتر   شامپو ضد ریزش
# 456  تونیک ضد ریزش مو سریتا مدل مینوتا حجم 50 میلی ...   ضد ریزش سریتا
# 457  شامپو ضد شوره مو تگودر مدل ضد التهاب حجم 355 م...        شامپو ضد
# 458  شامپو مو ایروکس مدل ضد شوره حجم 200 میلی لیتر ...        شامپو ضد
# ..                                                 ...             ...
# 529                                 قطره چکان مدل شفاف        شفاف بیس
# 530                            سوت صدای مرغابی مدل حنا            صدای
# 531                 کفش پیاده روی دخترانه مدل Y-YEDS71       پیاده روی
# 532                      کفش مردانه کفش آداک مدل مجلسی             کفش
# 533                        کفش زنانه کفش آداک مدل ترکس             کفش
#
#      rescue_pool_rank  teacher_grade  \
# 454               1.0              0
# 455               3.0              0
# 456               6.0              1
# 457               7.0              0
# 458               8.0              0
# ..                ...            ...
# 529               7.0              0
# 530               8.0              0
# 531               5.0              2
# 532               6.0              1
# 533               7.0              1
#
#                                         teacher_reason
# 454  شامپوی ضد ریزش است، اما برند آن کلینیک است و ب...
# 455  نوع محصول شامپوی ضد ریزش است، اما برند درمالای...
# 456  برند سریتا و کاربرد ضد ریزش دارد، اما تونیک مو...
# 457  شامپوی ضد شوره از برند تگودر است؛ نه برند سریت...
# 458  شامپوی ضد شوره به‌همراه شامپو بدن ضد قارچ از ب...
# ..                                                 ...
# 529     قطره‌چکان پزشکی است و ارتباطی با اسپیکر ندارد.
# 530  سوت تقلید صدای مرغابی است و اسپیکر محسوب نمی‌شود.
# 531  نوع محصول کفش پیاده‌روی است، اما هیچ شواهدی در...
# 532  کفش مردانه رسمی است و برای پیاده‌روی طولانی طر...
# 533  کفش ورزشی زنانه است، اما در بررسی به اذیت‌کردن...
#
# [80 rows x 8 columns]
