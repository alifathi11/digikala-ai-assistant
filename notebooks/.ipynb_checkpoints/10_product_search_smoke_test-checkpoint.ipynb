# %% [markdown]
# # 10 — Product Search V2 Smoke Test
#
# This version fixes two issues observed in the first smoke test:
#
# 1. explicit brand intent receives a deterministic metadata boost;
# 2. raw review similarity is no longer treated as positive evidence.
#
# The top metadata candidates are reranked by one grounded LLM call
# that classifies review evidence as:
#
# `support / mixed / contradict / none`
#
# **No product indexes need to be rebuilt for this notebook.**

# %%
from pathlib import Path
import sys
import os

from dotenv import load_dotenv

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.rag.config import load_config
from src.rag.preprocessing.processor import TextProcessor
from src.rag.embedding.factory import EmbeddingFactory
from src.rag.product_search import (
    ProductFAISSIndex,
    ProductBM25Index,
    ProductMetadataRetriever,
    ProductSearchReranker,
)
from src.rag.runtime import load_retrieval_stack
from src.rag.generation import OpenAIJSONGenerator
from src.rag.pipeline.product_search import ProductSearchPipeline

load_dotenv()
# Out:
# True

# %%
rag_config = load_config(
    PROJECT_ROOT
    / "configs"
    / "rag.yaml"
)

qa_config = load_config(
    PROJECT_ROOT
    / "configs"
    / "qa.yaml"
)

search_config = load_config(
    PROJECT_ROOT
    / "configs"
    / "product_search.yaml"
)

processor = TextProcessor()

embedding_model = (
    EmbeddingFactory.create(
        provider=rag_config[
            "embedding"
        ]["provider"],
        model_name=rag_config[
            "embedding"
        ]["model"],
    )
)

dense_index = (
    ProductFAISSIndex()
    .load(
        PROJECT_ROOT
        / "data"
        / "indexes"
        / "products_embedding"
    )
)

sparse_index = (
    ProductBM25Index(
        processor=processor
    )
    .load(
        PROJECT_ROOT
        / "data"
        / "indexes"
        / "products_bm25_tantivy"
    )
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
metadata_cfg = (
    search_config[
        "product_search"
    ][
        "metadata"
    ]
)

metadata_retriever = (
    ProductMetadataRetriever(
        embedding_model=embedding_model,
        dense_index=dense_index,
        sparse_index=sparse_index,
        processor=processor,
        bm25_weight=metadata_cfg[
            "bm25_weight"
        ],
        embedding_weight=metadata_cfg[
            "embedding_weight"
        ],
        candidate_multiplier=metadata_cfg[
            "candidate_multiplier"
        ],
        brand_boost=metadata_cfg[
            "brand_boost"
        ],
    )
)

review_stack = (
    load_retrieval_stack(
        project_root=PROJECT_ROOT
    )
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
reranker_cfg = (
    search_config[
        "product_search"
    ][
        "reranker"
    ]
)

reranker_generator = (
    OpenAIJSONGenerator(
        api_key=os.getenv(
            "METIS_API_KEY"
        ),
        base_url=os.getenv(
            "METIS_BASE_URL"
        ),
        model=qa_config[
            "generation"
        ]["model"],
        input_cost_per_million=(
            qa_config[
                "generation"
            ].get(
                "input_cost_per_million"
            )
        ),
        output_cost_per_million=(
            qa_config[
                "generation"
            ].get(
                "output_cost_per_million"
            )
        ),
    )
)

reranker = (
    ProductSearchReranker(
        generator=reranker_generator,
        max_reviews_per_product=(
            reranker_cfg[
                "max_reviews_per_product"
            ]
        ),
        max_review_chars=(
            reranker_cfg[
                "max_review_chars"
            ]
        ),
    )
)

candidate_cfg = (
    search_config[
        "product_search"
    ][
        "candidates"
    ]
)

search = ProductSearchPipeline(
    metadata_retriever=metadata_retriever,
    review_retriever=review_stack.hybrid,
    reranker=reranker,
    metadata_candidates=(
        candidate_cfg[
            "metadata_products"
        ]
    ),
    review_comment_candidates=(
        candidate_cfg[
            "review_comments"
        ]
    ),
    reranker_candidates=(
        candidate_cfg[
            "reranker_products"
        ]
    ),
    metadata_weight=(
        reranker_cfg[
            "metadata_weight"
        ]
    ),
    reranker_weight=(
        reranker_cfg[
            "llm_weight"
        ]
    ),
)

# %%
queries = [
    "ضد آفتاب پوست چرب که جوش نزنه",
    "شامپو ضد ریزش سریتا",
    "کرم آبرسان سبک و زود جذب",
]

for query in queries:
    print()
    print("QUERY:", query)

    results = search.search(
        query,
        top_k=10,
    )

    display(
        results[
            [
                "id",
                "title_fa",
                "Brand",
                "Category1",
                "Price",
                "score",
                "metadata_score",
                "brand_match",
                "llm_match_score",
                "evidence_status",
                "evidence_ids",
                "reason",
            ]
        ]
    )

    print(
        "Reranker telemetry:",
        results.attrs.get(
            "telemetry"
        )
    )
# Out:
# QUERY: ضد آفتاب پوست چرب که جوش نزنه
#          id                                           title_fa   Brand  \
# 0  10985328  فلوئید ضد آفتاب بی رنگ نوکس SPF50 مدل LIGHT من...    نوکس
# 1   6733478  فلوئید ضد آفتاب بی رنگ الارو SPF50 مدل Ultra L...   الارو
# 2  11286406  فلوئید ضد آفتاب بی رنگ اوریاژ +SPF50 مدل Hysea...  اوریاژ
# 3  12243791  کرم ضد آفتاب بدون رنگ SPF 30 تینولا مدل Tino S...  متفرقه
# 4  12390858  کرم ضد آفتاب بدون رنگ سیلوژه SPF 50 مدل TEXTUR...  سیلوژه
# 5   1110394  کرم ضد آفتاب رنگی اریکه مدل SPF50 مناسب پوست ه...   اریکه
# 6   5536401  کرم ضد آفتاب رنگی سینره +SPF60 مدل 8411 مناسب ...   سینره
# 7  12271621  کرم ضد آفتاب بدون رنگ ژوت SPF 50 مدل smooth si...     ژوت
# 8    183277  کرم ضد آفتاب رنگی الارو SPF50 مدل Teinte Fonce...   الارو
# 9  12550788  کرم ضد آفتاب رنگی اریکه SPF 50 مدل Solarie And...   اریکه
#
#      Category1       Price     score  metadata_score  brand_match  \
# 0  مراقبت پوست  12850000.0  0.860000        0.760876          0.0
# 1  مراقبت پوست   4141400.0  0.800593        0.740281          0.0
# 2  مراقبت پوست  11500000.0  0.748906        0.722362          0.0
# 3  مراقبت پوست   4050000.0  0.705485        0.707309          0.0
# 4  مراقبت پوست   2450000.0  0.517993        0.642310          0.0
# 5  مراقبت پوست   3700000.0  0.418029        0.607655          0.0
# 6  مراقبت پوست   1920000.0  0.385092        0.547702          0.0
# 7  مراقبت پوست   1950000.0  0.318149        0.573029          0.0
# 8  مراقبت پوست   4134100.0  0.304506        0.544032          0.0
# 9  مراقبت پوست   3998000.0  0.265366        0.554731          0.0
#
#    llm_match_score evidence_status          evidence_ids  \
# 0              3.0            none                    []
# 1              3.0            none                    []
# 2              3.0            none                    []
# 3              3.0            none                    []
# 4              3.0            none                    []
# 5              3.0         support            [25512563]
# 6              5.0         support  [50773924, 49313559]
# 7              3.0            none                    []
# 8              4.0         support             [1265177]
# 9              3.0            none                    []
#
#                                               reason
# 0  ضدآفتاب مناسب پوست چرب است، اما شواهدی درباره ...
# 1  برای پوست چرب و مختلط طراحی شده، اما شواهدی از...
# 2  ضدآفتاب مناسب پوست چرب و مختلط است، ولی درباره...
# 3  در دسته ضدآفتاب و مناسب پوست چرب است، اما شواه...
# 4  ضدآفتاب SPF50 مناسب پوست چرب و مختلط است، ولی ...
# 5  برای پوست چرب است و یک کاربر سبکی آن را تأیید ...
# 6  مناسب پوست چرب است و کاربران سبکی، چرب‌نبودن و...
# 7  ضدآفتاب SPF50 مناسب پوست چرب است، اما مدرکی در...
# 8  برای پوست چرب است و کاربر جذب عالی و چرب‌نشدن ...
# 9  برای پوست چرب و آکنه‌ای معرفی شده، اما شواهد ک...
# Reranker telemetry: {'reranker_applied': True, 'model': 'gpt-5.6-terra', 'latency_ms': 15064.91000999813, 'prompt_tokens': 1575, 'completion_tokens': 1065, 'total_tokens': 2640, 'estimated_cost_usd': None}
#
# QUERY: شامپو ضد ریزش سریتا
#          id                                           title_fa  Brand  \
# 0  11254633  شامپو تقویت کننده و ضد ریزش مو سریتا مدل جوانه...  سریتا
# 1    711943  شامپو ضد ریزش سریتا مدل پرومین مناسب برای موها...  سریتا
# 2   6552521  شامپو تقویت کننده و ضد ریزش سریتا مدل Fortifyi...  سریتا
# 3   8021274  شامپو ضد ریزش مو سریتا مدل مینوتا حجم 200 میلی...  سریتا
# 4   6506826  شامپو تقویت کننده و ضد ریزش مو سریتا مدل قهوه ...  سریتا
# 5   3832629  شامپو ضد ریزش مو سریتا مدل مینوتا مناسب برای م...  سریتا
# 6    476822  تونیک ضد ریزش مو سریتا مدل پرومین حجم 60 میلی ...  سریتا
# 7    471119  شامپو تقویت کننده و ضد ریزش مو سریتا مدل Forti...  سریتا
# 8    471187  شامپو تقویت کننده و ضد ریزش سریتا مدل کافئین م...  سریتا
# 9   8020989  شامپو تقویت کننده و ضد ریزش مو سریتا مدل 03 حج...  سریتا
#
#            Category1      Price     score  metadata_score  brand_match  \
# 0  شامپو و مراقبت مو   909800.0  0.930000        0.724250          1.0
# 1  شامپو و مراقبت مو  2863000.0  0.619989        0.641950          1.0
# 2  شامپو و مراقبت مو   748000.0  0.587160        0.650000          1.0
# 3  شامپو و مراقبت مو  2240000.0  0.506432        0.632516          1.0
# 4  شامپو و مراقبت مو   940000.0  0.501081        0.646518          1.0
# 5  شامپو و مراقبت مو   879000.0  0.498421        0.615621          1.0
# 6  شامپو و مراقبت مو  1695000.0  0.411257        0.642224          1.0
# 7  شامپو و مراقبت مو   640000.0  0.350000        0.583477          1.0
# 8  شامپو و مراقبت مو   870000.0  0.350000        0.583477          1.0
# 9  شامپو و مراقبت مو  1438500.0  0.280000        0.583477          1.0
#
#    llm_match_score evidence_status          evidence_ids  \
# 0              4.0            none                    []
# 1              5.0         support  [54226138, 40654587]
# 2              4.0            none                    []
# 3              4.0            none                    []
# 4              3.0            none                    []
# 5              5.0         support  [45580106, 42749138]
# 6              2.0            none                    []
# 7              5.0         support            [48311425]
# 8              5.0         support  [53674311, 53134200]
# 9              4.0            none                    []
#
#                                               reason
# 0  شامپو ضد ریزش از برند سریتا است، اما شواهد برر...
# 1  شامل شامپو ضد ریزش سریتا است و بررسی‌ها اثربخش...
# 2  شامپو تقویت‌کننده و ضد ریزش سریتا است، اما شوا...
# 3  مجموعه دوعددی شامپو ضد ریزش سریتا است، اما شوا...
# 4  از نظر برند و نوع شامپوی ضد ریزش مطابق است، ام...
# 5  شامپو ضد ریزش سریتا است و بررسی‌ها رضایت و کاه...
# 6   محصول ضد ریزش سریتا است اما تونیک است، نه شامپو.
# 7  شامپو تقویت‌کننده و ضد ریزش سریتا است و بررسی ...
# 8  شامپو ضد ریزش سریتا است و بررسی‌ها کاهش ریزش و...
# 9  مجموعه دوعددی شامپو تقویت‌کننده و ضد ریزش سریت...
# Reranker telemetry: {'reranker_applied': True, 'model': 'gpt-5.6-terra', 'latency_ms': 9007.076624002366, 'prompt_tokens': 1474, 'completion_tokens': 680, 'total_tokens': 2154, 'estimated_cost_usd': None}
#
# QUERY: کرم آبرسان سبک و زود جذب
#          id                                           title_fa      Brand  \
# 0   3347106   کرم آبرسان پانی دراگ مدل Light حجم 150 میلی لیتر  پانی دراگ
# 1   6410900   کرم روشن کننده آرتوینا مدل خیار حجم 50 میلی لیتر     متفرقه
# 2   9585339                   کرم آبرسان ناک مدل حاوی پروپولیس        ناک
# 3   2225386   کرم روشن کننده روجا مدل رازیانه حجم 70 میلی لیتر     متفرقه
# 4  11681924  کرم مرطوب کننده ژونزک مدل light moisturizing ح...      ژونزک
# 5   2952987   کرم مرطوب کننده لایسل مدل light حجم 50 میلی لیتر      لایسل
# 6  11611876  کرم روشن کننده توتال درم مدل INTENSE حجم 30 می...  توتال درم
# 7   1053845  کرم روشن کننده پریم مدل Intensive حجم 30 میلی ...       پریم
# 8  11063396  کرم مرطوب کننده کامان مدل light حجم 200 میلی لیتر      کامان
# 9   6282840  کرم آبرسان زیکسار مدل آبرسان و ضد چروک حجم 50 ...     زیکسار
#
#      Category1       Price     score  metadata_score  brand_match  \
# 0  مراقبت پوست    432000.0  0.930000        0.600000          0.0
# 1  مراقبت پوست   3550000.0  0.507932        0.522293          0.0
# 2  مراقبت پوست   1453600.0  0.507805        0.470946          0.0
# 3  مراقبت پوست    450000.0  0.482094        0.512825          0.0
# 4  مراقبت پوست  25000000.0  0.420030        0.413133          0.0
# 5  مراقبت پوست   1441000.0  0.343536        0.385104          0.0
# 6  مراقبت پوست   4000000.0  0.313942        0.451209          0.0
# 7  مراقبت پوست   3149500.0  0.295820        0.444569          0.0
# 8  مراقبت پوست    924000.0  0.286110        0.364061          0.0
# 9  مراقبت پوست   1852200.0  0.210000        0.361822          0.0
#
#    llm_match_score evidence_status evidence_ids  \
# 0              4.0            none           []
# 1              1.0            none           []
# 2              3.0            none           []
# 3              1.0            none           []
# 4              4.0            none           []
# 5              4.0            none           []
# 6              1.0            none           []
# 7              1.0            none           []
# 8              4.0            none           []
# 9              3.0            none           []
#
#                                               reason
# 0  کرم آبرسان با عنوان مدل Light است، اما شواهدی ...
# 1  کرم روشن‌کننده است و تطابق مشخصی با درخواست آب...
# 2  کرم آبرسان است، اما برای سبک بودن و جذب سریع ش...
# 3  این محصول در دسته کرم روشن‌کننده است، نه آبرسا...
# 4  کرم مرطوب‌کننده با عنوان light moisturizing اس...
# 5  کرم مرطوب‌کننده با مدل light است، اما مدرکی بر...
# 6  کرم روشن‌کننده است و نیاز اصلی کاربر به آبرسان...
# 7  محصول روشن‌کننده است و شواهدی از آبرسانی سبک و...
# 8  کرم مرطوب‌کننده با مدل light است، ولی شواهدی ا...
# 9  کرم آبرسان است، اما اطلاعاتی برای سبک بودن و ج...
# Reranker telemetry: {'reranker_applied': True, 'model': 'gpt-5.6-terra', 'latency_ms': 11697.806686999684, 'prompt_tokens': 1252, 'completion_tokens': 890, 'total_tokens': 2142, 'estimated_cost_usd': None}
